# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import tensorflow as tf
from aml_dl.mdn.model import tf_pushing_model

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import math

# %%
KMIX = 2

# %%
net = tf_pushing_model(dim_input = 4, n_hidden = 1, n_kernels = KMIX)

# %%
sess = tf.InteractiveSession()
sess.run(tf.initialize_all_variables())

# %% [markdown]
# ## Load data

# %%
from aml_robot.box2d.data_manager import DataManager

# %%
data_manager = DataManager.from_file('data_test.pkl')

# %%
print data_manager.get_sample(0,'push_action')
# Out:
# [[ 0.          0.         -0.93809723  0.34637204  2.78789168]]

# %%
data_x = data_manager.pack_data_x(['state_start','state_end'])

# %%
data_y = data_manager.pack_data_y()

# %%
print data_y
# Out:
# [[2.7878916847881401], [3.4576186235141271], [0.17273928666575863], [0.75176172504468186], [6.1231861400927183], [1.7537467231729578], [0.30514956372042612], [4.5440562147213148], [3.9804844517037195], [3.2010545671474193], [0.34986422232216441], [3.6673537530440878], [1.8482862573701027], [6.1686556263463705], [2.4938029649747904], [2.3999914650808183], [1.9661474474230822], [4.9283654218260295], [2.4026829181621752], [4.6399232356168261], [3.6202584650862231], [4.3751519542790556], [2.3318719413533899], [3.6303423117761531], [2.8148967559911249], [4.3129633379920058], [3.4620265986517356], [4.1860511137561423], [1.5684053892704386], [4.6444187882982062], [4.8885899071551533], [4.5070980656719133], [0.020684804063376416], [4.3948196260879788], [2.381840229066964], [5.0292226978235108], [3.5959306701395568], [3.3973721453729104], [0.65835996705823552], [5.7425927192742758], [4.9245961186400953], [3.5662178263211812], [1.3940686275028629], [4.843030779405443], [5.8051331918660347], [5.6758709871878459], [1.8451078609512361], [5.1922290788579231], [2.4111668333339349], [5.9647802023709842], [1.9182348817203507], [4.924397820411925], [6.2275017799987218], [1.6460564548756778], [3.3658212756360903], [3.7039719104802633], [2.1453555569800931], [3.8469187730128618], [4.4215074237133356], [3.2395825089966266], [2.1388325587030654], [5.9831004053868657], [2.7659987723135302], [0.04232767769057063], [0.93848013858188839], [6.1651893712648631], [2.8034245155835795], [3.8149285561867052], [2.9036498646160713], [0.93659818382285165], [3.7677937592274811], [2.2414894749084553], [6.0654384861224813], [5.3082983572406262], [5.0074986143689824], [3.41033815189164], [5.2614288276264531], [6.2034435423849805], [4.3432928478627213], [2.2070479803212111], [0.23377099632410675], [0.14177827338990792], [1.6298281671090138], [0.82536237352855135], [1.4321561550894544], [4.0041015854107895], [5.3333599768687705], [0.34420768621654935], [0.47059221067300572], [5.3407421922223959], [5.5386422876924888], [4.0464219968861475], [4.7477407607944615], [1.3395410783934301], [2.4751074287541943], [2.1354168784863097], [1.6305244544790169], [3.366809131588226], [3.1568247243473162], [0.42093131985487786], [5.368941816193975], [3.2095936267648244], [4.5020138887517742], [2.1998268094455846], [4.4225161545399194], [1.5242081923843755], [3.8927206105455032], [3.035046070701009], [1.0381703342279844], [1.9602016010186867], [4.8555195610248179], [4.0972399434923181], [5.1863013628937926], [2.423374053653168], [4.6127053493256183], [5.928991402526524], [3.973754004946132], [2.0354968305470473], [4.9028264200578375], [5.380720158905107], [2.3577144951128899], [3.7086785630846442], [5.337894201475323], [4.0220192762148717], [2.1330726190833684], [0.41212264959526684], [1.56575994078388], [3.9723990501106741], [2.9830905381538719], [1.9115644498967863], [5.7710162621779766], [3.3194726683386864], [1.7455003613716857], [5.7328772519656068], [0.18112230656883177], [1.460971343327486], [0.041094156112899918]]

# %%
h = sess.run(net['z_hidden'],feed_dict={net['x']: data_x})

# %%
plt.figure(figsize=(8, 8))
plt.plot(h, data_y,'ro', alpha=0.3)
plt.show()

# %%
N_EPOCHS = 5000#10000
loss = np.zeros(N_EPOCHS) # store the training progress here.
for i in range(N_EPOCHS):
  sess.run(net['train'],feed_dict={net['x']: data_x, net['y']: data_y})
  loss[i] = sess.run(net['loss'], feed_dict={net['x']: data_x, net['y']: data_y})

# %%
plt.figure(figsize=(8, 8))
plt.plot(np.arange(100, N_EPOCHS,1), loss[100:], 'r-')
plt.show()

# %%
N_SAMPLES = 100
print N_SAMPLES
x_test = np.float32(np.random.uniform(-5.5, 5.5, (4, N_SAMPLES))).T
len(x_test)
# Out:
# 200
# 200

# %%
h_test = sess.run(net['z_hidden'],feed_dict={net['x']: x_test})
NTEST = h_test.size
print NTEST
# x_test = x_test.reshape(NTEST,1) # needs to be a matrix, not a vector

def get_pi_idx(x, pdf):
  N = pdf.size
  accumulate = 0
  for i in range(0, N):
    accumulate += pdf[i]
    if (accumulate >= x):
      return i
  print 'error with sampling ensemble'
  return -1

def generate_ensemble(out_pi, out_mu, out_sigma, M = 10):
  NTEST = h_test.size
  result = np.random.rand(NTEST, M) # initially random [0, 1]
  rn = np.random.randn(NTEST, M) # normal random matrix (0.0, 1.0)
  mu = 0
  std = 0
  idx = 0

  # transforms result into random ensembles
  for j in range(0, M):
    for i in range(0, NTEST):
      idx = get_pi_idx(result[i, j], out_pi[i])
      mu = out_mu[i, idx]
      std = out_sigma[i, idx]
      result[i, j] = mu + rn[i, j]*std
  return result
# Out:
# 400

# %%
out_pi_test, out_sigma_test, out_mu_test = sess.run([net['pi'], net['sigma'], net['mu']], feed_dict={net['x']: x_test})

y_test = generate_ensemble(out_pi_test, out_mu_test, out_sigma_test)

plt.figure(figsize=(8, 8))
plt.plot(h,data_y,'ro', h_test,y_test,'bo',alpha=0.1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-1205ee364305> in <module>()
#       1 out_pi_test, out_sigma_test, out_mu_test = sess.run([net['pi'], net['sigma'], net['mu']], feed_dict={net['x']: x_test})
#       2
# ----> 3 y_test = generate_ensemble(out_pi_test, out_mu_test, out_sigma_test)
#       4
#       5 plt.figure(figsize=(8, 8))
#
# <ipython-input-19-63b69ccb951a> in generate_ensemble(out_pi, out_mu, out_sigma, M)
#      24   for j in range(0, M):
#      25     for i in range(0, NTEST):
# ---> 26       idx = get_pi_idx(result[i, j], out_pi[i])
#      27       mu = out_mu[i, idx]
#      28       std = out_sigma[i, idx]
#
# IndexError: index 100 is out of bounds for axis 0 with size 100

# %%
plt.figure(figsize=(8, 8))
plt.plot(h_test,out_mu_test,'go', h_test,y_test,'bo',alpha=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-43120a324d98> in <module>()
#       1 plt.figure(figsize=(8, 8))
# ----> 2 plt.plot(h_test,out_mu_test,'go', h_test,y_test,'bo',alpha=0.3)
#       3 plt.show()
#
# NameError: name 'y_test' is not defined

# %%
len(out_pi_test)
x_heatmap_label = np.float32(np.arange(-5,5,0.1))
y_heatmap_label = np.float32(np.arange(-5,5,0.1))

len(x_heatmap_label)
# Out:
# 100

# %%
def custom_gaussian(x, mu, std):
  oneDivSqrtTwoPI = 1 / math.sqrt(2*math.pi)
  x_norm = (x-mu)/std
  result = oneDivSqrtTwoPI*math.exp(-x_norm*x_norm/2)/std
  return result

def generate_heatmap(out_pi, out_mu, out_sigma, x_heatmap_label, y_heatmap_label):
  N = x_heatmap_label.size
  M = y_heatmap_label.size
  K = KMIX

  z = np.zeros((N, M)) # initially random [0, 1]

  mu = 0
  std = 0
  pi = 0

  # transforms result into random ensembles
  for k in range(0, K):
    for i in range(0, M):
      pi = out_pi[i, k]
      mu = out_mu[i, k]
      std = out_sigma[i, k]
      for j in range(0, N):
        z[N-j-1, i] += pi * custom_gaussian(y_heatmap_label[j], mu, std)

  return z

def draw_heatmap(xedges, yedges, heatmap):
  extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]
  plt.figure(figsize=(8, 8))
  plt.imshow(heatmap, extent=extent)
  plt.show()

z = generate_heatmap(out_pi_test, out_mu_test, out_sigma_test, x_heatmap_label, y_heatmap_label)
draw_heatmap(x_heatmap_label, y_heatmap_label, z)
